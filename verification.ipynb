# %%
# plot wave elevation of a standing wave
import numpy as np
from matplotlib import pyplot as plt
wav_quad = np.loadtxt("wav_quad.dat", comments="#", delimiter=" ", unpack=False)
wav_tri = np.loadtxt("wav_tri.dat", comments="#", delimiter=" ", unpack=False)
time = np.linspace(0.,5.,1000)
af = 0.01
L = 0.8
h = 0.1
wn = math.sqrt(np.pi*9.81*np.tanh(np.pi*h/L)/L)
wav_exa = []
for i in range(len(time)):
    wav_exa.append(-af*np.pi/(wn*L)*np.sinh(np.pi*h/L)*np.sin(wn*time[i]))

plt.figure(1)
plt.plot(wav_quad[:,0],wav_quad[:,1],'-r',wav_tri[:,0],wav_tri[:,1],'-b',time,wav_exa,'--k')
plt.legend(['ALE-FEM-quadrilateral element','ALE-FEM-triangular element','exact solution'])
plt.xlabel('time (s)')
plt.ylabel('wave elevatoin (m)')
# Out:
# /tmp/ipykernel_3928863/182068958.py:4: UserWarning: loadtxt: Empty input file: "wav_quad.dat"
#   wav_quad = np.loadtxt("wav_quad.dat", comments="#", delimiter=" ", unpack=False)
# /tmp/ipykernel_3928863/182068958.py:5: UserWarning: loadtxt: Empty input file: "wav_tri.dat"
#   wav_tri = np.loadtxt("wav_tri.dat", comments="#", delimiter=" ", unpack=False)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_3928863/182068958.py in <module>
#       7
#       8 plt.figure(1)
# ----> 9 plt.plot(wav_quad[:,0],wav_quad[:,1],'-r',wav_tri[:,0],wav_tri[:,1],'-b',wav_bem[:,0],wav_bem[:,1],'--k')
#      10 plt.legend(['ALE-FEM-quadrilateral element','ALE-FEM-triangular element','EL-BEM'])
#      11 plt.xlabel('time (s)')
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
# plot wave elevation of a sloshing wave: ALE-FEM (quad) vs ALE-FEM (tri) vs EL-BEM
import numpy as np
from matplotlib import pyplot as plt
wav_quad = np.loadtxt("wav_quad.dat", comments="#", delimiter=" ", unpack=False)
wav_tri = np.loadtxt("wav_tri.dat", comments="#", delimiter=" ", unpack=False)
wav_bem = np.loadtxt("wav_bem_10.dat", comments="#", delimiter=" ", unpack=False)

plt.figure(1)
plt.figure(figsize=(12,6))
plt.plot(wav_quad[:,0],wav_quad[:,1],'-r',wav_tri[:,0],wav_tri[:,1],'-b',wav_bem[:,0],wav_bem[:,1],'--k')
plt.legend(['ALE-FEM-quadrilateral element','ALE-FEM-quadrilateral element','ALE-FEM-triangular element','EL-BEM'])
plt.xlabel('time (s)')
plt.ylabel('wave elevatoin (m)')
# Out:
# Text(0, 0.5, 'wave elevatoin (m)')

# %%
# plot wave elevation of a sloshing wave: moving frame vs inertia frame
import numpy as np
from matplotlib import pyplot as plt
wav_quad = np.loadtxt("wav_quad.dat", comments="#", delimiter=" ", unpack=False)
wav_quad2 = np.loadtxt("wav_quad_wmk.dat", comments="#", delimiter=" ", unpack=False)

plt.figure(1)
plt.figure(figsize=(12,6))
plt.plot(wav_quad[:,0],wav_quad[:,1],'-r',wav_quad2[:,0],wav_quad2[:,1],'--k')
plt.legend(['ALE-FEM-quadrilateral element-with homogeneous Neumann condition','ALE-FEM-quadrilateral element-with non-zero Neumann condition'])
plt.xlabel('time (s)')
plt.ylabel('wave elevatoin (m)')
# Out:
# Text(0, 0.5, 'wave elevatoin (m)')

# %%
# plot mass error
mas_quad = np.loadtxt("mass_quad.dat", comments="#", delimiter=" ", unpack=False)
mas_quad2 = np.loadtxt("mass_quad_wmk.dat", comments="#", delimiter=" ", unpack=False)
mas_tri = np.loadtxt("mass_tri.dat", comments="#", delimiter=" ", unpack=False)
plt.figure(1)
plt.plot(mas_quad[:,0],mas_quad[:,1],mas_quad2[:,0],mas_quad2[:,1])
plt.legend(['ALE-FEM-quadrilateral element-with homogeneous Neumann condition','ALE-FEM-quadrilateral element-with non-zero Neumann condition'])
plt.xlabel('time (s)')
plt.ylabel('mass error (%)')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_3928863/123187248.py in <module>
#       4 mas_tri = np.loadtxt("mass_tri.dat", comments="#", delimiter=" ", unpack=False)
#       5 plt.figure(1)
# ----> 6 plt.plot(mas_quad[:,0],mas_quad[:,1],mas_quad2[:,0],mas_quad2[:,1])
#       7 plt.legend(['ALE-FEM-quadrilateral element-with homogeneous Neumann condition','ALE-FEM-quadrilateral element-with non-zero Neumann condition'])
#       8 plt.xlabel('time (s)')
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
# Beji's problem
import numpy as np
from matplotlib import pyplot as plt
exp = np.loadtxt("sl.dat", comments="#", delimiter=",", unpack=False)

dt = 0.5
wav_quad = np.loadtxt("wav_quad_wmk.dat", comments="#", delimiter=",", unpack=False)
for i in range(7):
    plt.figure(i)
    plt.figure(figsize=(30,5))
    plt.xlim([0.,20])
    plt.plot(exp[:,0],exp[:,i+1],'ok',wav_quad[:,0]+dt,wav_quad[:,i+2]*100.)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3928863/1737256913.py in <module>
#       5
#       6 dt = 0.5
# ----> 7 wav_quad = np.loadtxt("wav_quad_wmk.dat", comments="#", delimiter=",", unpack=False)
#       8 for i in range(7):
#       9     plt.figure(i)
#
# /opt/proteus/linux/lib/python3.9/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1146         # converting the data
#    1147         X = None
# -> 1148         for x in read_data(_loadtxt_chunksize):
#    1149             if X is None:
#    1150                 X = np.array(x, dtype)
#
# /opt/proteus/linux/lib/python3.9/site-packages/numpy/lib/npyio.py in read_data(chunk_size)
#     997
#     998             # Convert each value according to its column and store
# --> 999             items = [conv(val) for (conv, val) in zip(converters, vals)]
#    1000
#    1001             # Then pack it according to the dtype's nesting
#
# /opt/proteus/linux/lib/python3.9/site-packages/numpy/lib/npyio.py in <listcomp>(.0)
#     997
#     998             # Convert each value according to its column and store
# --> 999             items = [conv(val) for (conv, val) in zip(converters, vals)]
#    1000
#    1001             # Then pack it according to the dtype's nesting
#
# /opt/proteus/linux/lib/python3.9/site-packages/numpy/lib/npyio.py in floatconv(x)
#     734         if '0x' in x:
#     735             return float.fromhex(x)
# --> 736         return float(x)
#     737
#     738     typ = dtype.type
#
# ValueError: could not convert string to float: '0.0 0.0 0.0 -5.551115123125783e-17 0.0 0.0 1.1102230246251565e-16 5.551115123125783e-17 0.0'

# %%
# !tar cvfz allfiles.tar.gz *
# Out:
# bvp_quadrilateral.ipynb
# bvp_triangular.ipynb
# C0000.png
# C0001.png
# C0002.png
# C0003.png
# C0004.png
# C0005.png
# C0006.png
# C0007.png
# C0008.png
# C0009.png
# C0010.png
# C0011.png
# C0012.png
# C0013.png
# C0014.png
# C0015.png
# C0016.png
# C0017.png
# C0018.png
# C0019.png
# C0020.png
# C0021.png
# C0022.png
# C0023.png
# C0024.png
# C0025.png
# C0026.png
# C0027.png
# C0028.png
# C0029.png
# C0030.png
# C0031.png
# C0032.png
# C0033.png
# C0034.png
# C0035.png
# C0036.png
# C0037.png
# C0038.png
# C0039.png
# C0040.png
# C0041.png
# C0042.png
# C0043.png
# C0044.png
# C0045.png
# C0046.png
# C0047.png
# C0048.png
# C0049.png
# C0050.png
# C0051.png
# C0052.png
# C0053.png
# C0054.png
# C0055.png
# C0056.png
# C0057.png
# C0058.png
# C0059.png
# C0060.png
# C0061.png
# C0062.png
# C0063.png
# C0064.png
# C0065.png
# C0066.png
# C0067.png
# C0068.png
# C0069.png
# C0070.png
# C0071.png
# C0072.png
# C0073.png
# C0074.png
# C0075.png
# C0076.png
# C0077.png
# C0078.png
# C0079.png
# C0080.png
# C0081.png
# C0082.png
# C0083.png
# C0084.png
# C0085.png
# C0086.png
# C0087.png
# C0088.png
# C0089.png
# C0090.png
# C0091.png
# C0092.png
# C0093.png
# C0094.png
# C0095.png
# C0096.png
# C0097.png
# C0098.png
# C0099.png
# C0100.png
# C0101.png
# C0102.png
# C0103.png
# C0104.png
# C0105.png
# C0106.png
# C0107.png
# C0108.png
# C0109.png
# C0110.png
# C0111.png
# C0112.png
# C0113.png
# C0114.png
# C0115.png
# C0116.png
# C0117.png
# C0118.png
# C0119.png
# C0120.png
# C0121.png
# C0122.png
# C0123.png
# C0124.png
# C0125.png
# C0126.png
# C0127.png
# C0128.png
# C0129.png
# C0130.png
# C0131.png
# C0132.png
# C0133.png
# C0134.png
# C0135.png
# C0136.png
# C0137.png
# C0138.png
# C0139.png
# C0140.png
# C0141.png
# C0142.png
# C0143.png
# C0144.png
# C0145.png
# C0146.png
# C0147.png
# C0148.png
# C0149.png
# C0150.png
# C0151.png
# C0152.png
# C0153.png
# C0154.png
# C0155.png
# C0156.png
# C0157.png
# C0158.png
# C0159.png
# C0160.png
# C0161.png
# C0162.png
# C0163.png
# C0164.png
# C0165.png
# C0166.png
# C0167.png
# C0168.png
# C0169.png
# C0170.png
# C0171.png
# C0172.png
# C0173.png
# C0174.png
# C0175.png
# C0176.png
# C0177.png
# C0178.png
# C0179.png
# C0180.png
# C0181.png
# C0182.png
# C0183.png
# C0184.png
# C0185.png
# C0186.png
# C0187.png
# C0188.png
# C0189.png
# C0190.png
# C0191.png
# C0192.png
# C0193.png
# C0194.png
# C0195.png
# C0196.png
# C0197.png
# C0198.png
# C0199.png
# mass_quad.dat
# mass_quad_wmk.dat
# mass_tri.dat
# README.md
# slo_exp_09.dat
# sloshing_quadrilateral.ipynb
# sloshing_triangular.ipynb
# test.txt
# verification.ipynb
# wav_bem_09.dat
# wav_bem_10.dat
# wavemaker.ipynb
# wavemaker_quadrilateral.ipynb
# wav_quad.dat
# wav_quad_wmk.dat
# wav_tri.dat
